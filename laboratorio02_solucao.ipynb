# %% [markdown]
# #### Laboratório 02 Atividade de fixacao: Arrays

# %%
# Exercício 01
A= [10 20 30;40 50 60]
# Out:
# 2×3 Matrix{Int64}:
#  10  20  30
#  40  50  60

# %%
# Exibir tamanho
println("Tamanho da matriz: ", size(A))
# Out:
# Tamanho da matriz: (2, 3)

# %%
# Acessar A[2,3] (Segunda linha, Terceira coluna)
println("Elemento A[2,3]: ", A[2,3])
# Out:
# Elemento A[2,3]: 60

# %%
# Transposta
println("Matriz Transposta:")
display(A')
# Out:
# 3×2 adjoint(::Matrix{Int64}) with eltype Int64:
#  10  40
#  20  50
#  30  60
# Matriz Transposta:

# %%
# Exercício 02 
v = [0, 2, 4, 6 ,8 , 10]
# Out:
# 6-element Vector{Int64}:
#   0
#   2
#   4
#   6
#   8
#  10

# %%
v2 = v .^2
# Out:
# 6-element Vector{Int64}:
#    0
#    4
#   16
#   36
#   64
#  100

# %%
# Projeto 02
