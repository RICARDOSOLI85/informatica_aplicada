# %% [markdown]
# # Julia no Notebook

# %%
1/3
# Out:
# 0.3333333333333333

# %% [markdown]
# ### texto

# %%
println("Hello World")
# Out:
# Hello World

# %%
1+1
# Out:
# 2

# %%
10/9
# Out:
# 1.1111111111111112

# %%
sqrt(9)
# Out:
# 3.0

# %%
cbrt(27)
# Out:
# 3.0

# %%
10>3
# Out:
# true

# %%
10 == 10
# Out:
# true

# %%
10 != 100
# Out:
# true

# %%
true && true
# Out:
# true

# %%
 10 > 3 && 4 > 1
# Out:
# true

# %%
 10 > 3 && 4 > 6
# Out:
# false

# %%
true || false
# Out:
# true

# %%
false || false
# Out:
# false

# %% [markdown]
# Operadores

# %%
2 > 1 ? "SIM" : "NÃO"
# Out:
# "SIM"

# %%
'a'
# Out:
# 'a': ASCII/Unicode U+0061 (category Ll: Letter, lowercase)

# %%
"Hello" * "Hello"
# Out:
# "HelloHello"

# %%
"a"^30
# Out:
# "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa"

# %%
sin(100)
# Out:
# -0.5063656411097588

# %%
cos(100)
# Out:
# 0.8623188722876839

# %%
tan(100)
# Out:
# -0.5872139151569291

# %%
1+1/2
# Out:
# 1.5

# %%
(1+1)/2
# Out:
# 1.0

# %%
10 > 5 > 3 > 1 # comparação em ordem direta
# Out:
# true

# %%
1/0   # viloação matemática
# Out:
# Inf

# %%
0/0 # not a namber
# Out:
# NaN

# %%
0.1 + 0.2 == 0.3 # ponto flutuante
# Out:
# false

# %%
1 + 1im
# Out:
# 1 + 1im

# %%
-1 + 0im
# Out:
# -1 + 0im

# %%
sqrt(-1 + 0im)
# Out:
# 0.0 + 1.0im

# %%
variavel = "Hello"
# Out:
# "Hello"

# %%
 println(variavel)
# Out:
# Hello

# %%
variavel = "Hello"
# Out:
# "Hello"

# %%
println(variavel)
# Out:
# Hello

# %%
ponto = 4.4
# Out:
# 4.4

# %%
pontdois = ponto ^ 2
# Out:
# 19.360000000000003

# %%
f(x) = 20x - 100 # modo fx
# Out:
# f (generic function with 1 method)

# %%
function f(x)
    return 2x - 100 
end
# Out:
# f (generic function with 1 method)

# %%
function f(x)
    2x - 100 
end
# Out:
# f (generic function with 1 method)
